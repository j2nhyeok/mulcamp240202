# %%
import pandas as pd
import plotly

# %% [markdown]
# ## 서울시 아파트/오피스텔/단독다가구/연립다세대 전세 평균가격 추이

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/seoul_all.csv', encoding='euc_kr')

# 'RENT_GBN'이 '전세'이고 'HOUSE_GBN_NM'이 '아파트'인 행들만 필터링
df = df[(df['RENT_GBN'] == '전세') & (df['HOUSE_GBN_NM'] == '아파트')]

df = df[['RENT_GTN', 'CNTRCT_DE']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['CNTRCT_DE'].astype(str).str[:-2])['RENT_GTN'].mean().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='CNTRCT_DE',
    y='RENT_GTN',
    title='서울 월별 아파트 전세 평균가격',
    labels={'CNTRCT_DE': '월', 'RENT_GTN': '평균 전세 가격(만원)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)

# y-axis tick 포맷 변경 (5억 단위로)
fig.update_yaxes(tickformat=",d")

# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_24000\2436767045.py:5: DtypeWarning:
#
# Columns (16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/seoul_all.csv', encoding='euc_kr')

# 'RENT_GBN'이 '전세'이고 'HOUSE_GBN_NM'이 '오피스텔'인 행들만 필터링
df = df[(df['RENT_GBN'] == '전세') & (df['HOUSE_GBN_NM'] == '오피스텔')]

df = df[['RENT_GTN', 'CNTRCT_DE']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['CNTRCT_DE'].astype(str).str[:-2])['RENT_GTN'].mean().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='CNTRCT_DE',
    y='RENT_GTN',
    title='서울 월별 오피스텔 전세 평균가격',
    labels={'CNTRCT_DE': '월', 'RENT_GTN': '평균 전세 가격(만원)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)

# y-axis tick 포맷 변경 (5억 단위로)
fig.update_yaxes(tickformat=",d")

# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_24000\1061035661.py:5: DtypeWarning:
#
# Columns (16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/seoul_all.csv', encoding='euc_kr')

# 'RENT_GBN'이 '전세'이고 'HOUSE_GBN_NM'이 '연립다세대'인 행들만 필터링
df = df[(df['RENT_GBN'] == '전세') & (df['HOUSE_GBN_NM'] == '연립다세대')]

df = df[['RENT_GTN', 'CNTRCT_DE']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['CNTRCT_DE'].astype(str).str[:-2])['RENT_GTN'].mean().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='CNTRCT_DE',
    y='RENT_GTN',
    title='서울 월별 연립다세대 전세 평균가격',
    labels={'CNTRCT_DE': '월', 'RENT_GTN': '평균 전세 가격(만원)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)

# y-axis tick 포맷 변경 (5억 단위로)
fig.update_yaxes(tickformat=",d")

# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_24000\3035924215.py:5: DtypeWarning:
#
# Columns (16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/seoul_all.csv', encoding='euc_kr')

# 'RENT_GBN'이 '전세'이고 'HOUSE_GBN_NM'이 '단독다가구'인 행들만 필터링
df = df[(df['RENT_GBN'] == '전세') & (df['HOUSE_GBN_NM'] == '단독다가구')]

df = df[['RENT_GTN', 'CNTRCT_DE']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['CNTRCT_DE'].astype(str).str[:-2])['RENT_GTN'].mean().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='CNTRCT_DE',
    y='RENT_GTN',
    title='서울 월별 단독다가구 전세 평균가격',
    labels={'CNTRCT_DE': '월', 'RENT_GTN': '평균 전세 가격(만원)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)

# y-axis tick 포맷 변경 (5억 단위로)
fig.update_yaxes(tickformat=",d")

# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_24000\1253704739.py:5: DtypeWarning:
#
# Columns (16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
import pandas as pd
import plotly.express as px

def get_increase(df):
    df['계약년월'] = pd.to_datetime(df['계약년월'], format='%Y%m')

    # '보증금(만원)' 열의 쉼표 제거하고 숫자로 변환
    df['거래금액(만원)'] = df['거래금액(만원)'].replace({',': ''}, regex=True).astype(float)
    
    # 조건에 따라 데이터 필터링
    before_megaseoul = df[(df['계약년월'] <= '2023-09') & (df['계약년월'] >= '2023-06')]
    after_megaseoul = df[ (df['계약년월'] <= '2024-01') & (df['계약년월'] >= '2023-10')]
    
    before_mean = before_megaseoul['거래금액(만원)'].mean()
    after_mean = after_megaseoul['거래금액(만원)'].mean()
    
    # 증가율 계산
    increase_rate = ((after_mean - before_mean) / before_mean) * 100

    return increase_rate

increase_rate = []
# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('김포데이터/df_김포.csv')

gimpo_apart = df[df['주택유형']=='아파트']
gimpo_officetels = df[df['주택유형']=='오피스텔']
gimpo_multi_complex = df[df['주택유형']=='연립다세대']
# '계약년월'을 datetime 형식으로 변환

increase_rate.append(get_increase(gimpo_apart))
increase_rate.append(get_increase(gimpo_officetels))
increase_rate.append(get_increase(gimpo_multi_complex))

                     
# 그래프를 그리기 위한 데이터프레임 생성
data = {'Category': ['아파트', '오피스텔', '연립다세대'],
        'increase_rate': [increase_rate[0], increase_rate[1], increase_rate[2]]}
        

df_bar = pd.DataFrame(data)

# 막대 그래프 그리기
fig = px.bar(
    df_bar,
    x='Category',
    y='increase_rate',
    title='메가서울 발표 이후 김포시 평균 매매금액 증가/감소율',
    labels={'Category': '구분', 'increase_rate': '증가율'},
    template='plotly_dark',  # Dark mode template
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)


fig.update_yaxes(tickformat=',d')
# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_15452\903000834.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_15452\903000834.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_15452\903000834.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import pandas as pd
import plotly.express as px

def get_increase(df):
    df['계약년월'] = pd.to_datetime(df['계약년월'], format='%Y%m')
    # '보증금(만원)' 열의 쉼표 제거하고 숫자로 변환
    df['보증금(만원)'] = df['보증금(만원)'].replace({',': ''}, regex=True).astype(float)
    
    # 조건에 따라 데이터 필터링
    before_megaseoul = df[(df['전월세구분'] == '전세') & (df['계약년월'] <= '2023-09') & (df['계약년월'] >= '2023-06')]
    after_megaseoul = df[(df['전월세구분'] == '전세') & (df['계약년월'] <= '2024-01') & (df['계약년월'] >= '2023-10')]
    
    before_mean = before_megaseoul['보증금(만원)'].mean()
    after_mean = after_megaseoul['보증금(만원)'].mean()
    
    # 증가율 계산
    increase_rate = ((after_mean - before_mean) / before_mean) * 100

    return increase_rate

increase_rate = []
# CSV 파일을 읽어와 데이터프레임으로 저장

df = pd.read_csv('김포데이터/gimpo_all2.csv')
gimpo_apart = gimpo_all2[gimpo_all2['주택유형'] == '아파트']
gimpo_multi_complex = gimpo_all2[gimpo_all2['주택유형'] == '연립다세대']
gimpo_officetels = gimpo_all2[gimpo_all2['주택유형'] == '오피스텔']
# '계약년월'을 datetime 형식으로 변환

increase_rate.append(get_increase(gimpo_apart))
increase_rate.append(get_increase(gimpo_officetels))
increase_rate.append(get_increase(gimpo_multi_complex))

print(increase_rate)
                     
# 그래프를 그리기 위한 데이터프레임 생성
data = {'Category': ['아파트', '오피스텔', '연립다세대'],
        'increase_rate': [increase_rate[0], increase_rate[1], increase_rate[2]]}
        

df_bar = pd.DataFrame(data)

# 막대 그래프 그리기
fig = px.bar(
    df_bar,
    x='Category',
    y='increase_rate',
    title='메가서울 발표 이후 김포시 평균 전세 보증금 증가/감소율',
    labels={'Category': '구분', 'increase_rate': '증가율'},
    template='plotly_dark',  # Dark mode template
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)


fig.update_yaxes(tickformat=',d')
# Show the plot
fig.show()
# Out:
# [7.776438606854938, -2.7459519721735783, -3.313303728341426]
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_15452\957876131.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_15452\957876131.py:7: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_15452\957876131.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
import pandas as pd
import plotly.express as px

def get_increase(df):
    df['계약년월'] = pd.to_datetime(df['계약년월'], format='%Y%m')

    # '보증금(만원)' 열의 쉼표 제거하고 숫자로 변환
    df['보증금(만원)'] = df['보증금(만원)'].replace({',': ''}, regex=True).astype(float)
    
    # 조건에 따라 데이터 필터링
    before_megaseoul = df[(df['전월세구분'] == '월세') & (df['계약년월'] <= '2023-09') & (df['계약년월'] >= '2023-06')]
    after_megaseoul = df[(df['전월세구분'] == '월세') & (df['계약년월'] <= '2024-01') & (df['계약년월'] >= '2023-10')]
    
    before_mean = before_megaseoul['보증금(만원)'].mean()
    after_mean = after_megaseoul['보증금(만원)'].mean()
    
    # 증가율 계산
    increase_rate = ((after_mean - before_mean) / before_mean) * 100

    return increase_rate

increase_rate = []
# CSV 파일을 읽어와 데이터프레임으로 저장
gimpo_all2 = pd.read_csv('김포데이터/gimpo_all2.csv')

# '계약년월'을 datetime 형식으로 변환
gimpo_apart = gimpo_all2[gimpo_all2['주택유형'] == '아파트']
gimpo_multi_complex = gimpo_all2[gimpo_all2['주택유형'] == '연립다세대']
gimpo_officetels = gimpo_all2[gimpo_all2['주택유형'] == '오피스텔']

increase_rate.append(get_increase(gimpo_apart))
increase_rate.append(get_increase(gimpo_officetels))
increase_rate.append(get_increase(gimpo_multi_complex))

print(increase_rate)
                     
# 그래프를 그리기 위한 데이터프레임 생성
data = {'Category': ['아파트', '오피스텔', '연립다세대'],
        'increase_rate': [increase_rate[0], increase_rate[1], increase_rate[2]]}
        

df_bar = pd.DataFrame(data)

# 막대 그래프 그리기
fig = px.bar(
    df_bar,
    x='Category',
    y='increase_rate',
    title='메가서울 발표 이후 김포시 평균 보증금 증가/감소율',
    labels={'Category': '구분', 'increase_rate': '증가율'},
    template='plotly_dark',  # Dark mode template
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)


fig.update_yaxes(tickformat=',d')
# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_15452\532888266.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_15452\532888266.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_15452\532888266.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ## 서울 아파트/오피스텔/연립다세대/단독다가구 월세 보증금 변동 추이

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/seoul_all.csv', encoding='euc-kr')

# 'RENT_GBN'이 '전세'이고 'HOUSE_GBN_NM'이 '아파트'인 행들만 필터링
df = df[(df['RENT_GBN'] == '월세') & (df['HOUSE_GBN_NM'] == '아파트')]

df = df[['RENT_GTN', 'CNTRCT_DE']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['CNTRCT_DE'].astype(str).str[:-2])['RENT_GTN'].mean().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='CNTRCT_DE',
    y='RENT_GTN',
    title='서울 월별 아파트 월세 보증금 평균가격',
    labels={'CNTRCT_DE': '월', 'RENT_GTN': '평균 월세 보증금 가격(만원)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)

fig.update_yaxes(tickformat=",d")

# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_24000\2115536702.py:5: DtypeWarning:
#
# Columns (16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/seoul_all.csv', encoding='euc-kr')

# 'RENT_GBN'이 '월세'이고 'HOUSE_GBN_NM'이 '오피스텔'인 행들만 필터링
df = df[(df['RENT_GBN'] == '월세') & (df['HOUSE_GBN_NM'] == '오피스텔')]

df = df[['RENT_GTN', 'CNTRCT_DE']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['CNTRCT_DE'].astype(str).str[:-2])['RENT_GTN'].mean().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='CNTRCT_DE',
    y='RENT_GTN',
    title='서울 월별 오피스텔 월세 보증금 평균가격',
    labels={'CNTRCT_DE': '월', 'RENT_GTN': '평균 월세 보증금 가격(만원)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)

fig.update_yaxes(tickformat=",d")

# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_24000\3865670649.py:5: DtypeWarning:
#
# Columns (16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/seoul_all.csv', encoding='euc-kr')

# 'RENT_GBN'이 '월세'이고 'HOUSE_GBN_NM'이 '오피스텔'인 행들만 필터링
df = df[(df['RENT_GBN'] == '월세') & (df['HOUSE_GBN_NM'] == '연립다세대')]

df = df[['RENT_GTN', 'CNTRCT_DE']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['CNTRCT_DE'].astype(str).str[:-2])['RENT_GTN'].mean().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='CNTRCT_DE',
    y='RENT_GTN',
    title='서울 월별 연립다세대 월세 보증금 평균가격',
    labels={'CNTRCT_DE': '월', 'RENT_GTN': '평균 월세 보증금 가격(만원)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)

fig.update_yaxes(tickformat=",d")

# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_24000\841520546.py:5: DtypeWarning:
#
# Columns (16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/seoul_all.csv', encoding='euc-kr')

# 'RENT_GBN'이 '월세'이고 'HOUSE_GBN_NM'이 '오피스텔'인 행들만 필터링
df = df[(df['RENT_GBN'] == '월세') & (df['HOUSE_GBN_NM'] == '단독다가구')]

df = df[['RENT_GTN', 'CNTRCT_DE']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['CNTRCT_DE'].astype(str).str[:-2])['RENT_GTN'].mean().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='CNTRCT_DE',
    y='RENT_GTN',
    title='서울 월별 단독다가구 월세 보증금 평균가격',
    labels={'CNTRCT_DE': '월', 'RENT_GTN': '평균 월세 보증금 가격(만원)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)

fig.update_yaxes(tickformat=",d")

# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_24000\2414080666.py:5: DtypeWarning:
#
# Columns (16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.

# %% [markdown]
# ## 김포 전세

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('김포데이터/gimpo_apart.csv', encoding='euc_kr')

# '전월세구분'이 '전세'이고 'HOUSE_GBN_NM'이 '아파트'인 행들만 필터링
df = df[(df['전월세구분'] == '전세')]

# '계약년월'을 문자열로 변환 후 월 정보 추출
df['year_month'] = df['계약년월'].astype(str)

# '보증금(만원)' 열의 쉼표 제거하고 숫자로 변환
df['보증금(만원)'] = df['보증금(만원)'].str.replace(',', '').astype(float)



# 'year_month'를 월별로 그룹화하여 평균값 계산
monthly_data = df.groupby('year_month')['보증금(만원)'].mean().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='year_month',
    y='보증금(만원)',
    title='김포 월별 아파트 전세 평균가격',
    labels={'year_month': '월', '보증금(만원)': '전세(만원)'},
    template='plotly_dark',
    line_shape='linear',
    markers=True,
    width=800,
    height=400,
)

fig.update_yaxes(tickformat=",d")
fig.show()

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('김포데이터/gimpo_house.csv')

df = df[(df['전월세구분'] == '전세')]

# '계약년월'을 문자열로 변환 후 월 정보 추출
df['year_month'] = df['계약년월'].astype(str)

# '보증금(만원)' 열의 쉼표 제거하고 숫자로 변환
df['보증금(만원)'] = df['보증금(만원)'].str.replace(',', '').astype(float)



# 'year_month'를 월별로 그룹화하여 평균값 계산
monthly_data = df.groupby('year_month')['보증금(만원)'].mean().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='year_month',
    y='보증금(만원)',
    title='김포 월별 단독다가구 전세 평균가격',
    labels={'year_month': '월', '보증금(만원)': '전세(만원)'},
    template='plotly_dark',
    line_shape='linear',
    markers=True,
    width=800,
    height=400,
)

fig.update_yaxes(tickformat=",d")
fig.show()

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('김포데이터/gimpo_all2.csv')

df = df[(df['전월세구분'] == '전세') & (df['주택유형'] == '오피스텔')]

# '계약년월'을 문자열로 변환 후 월 정보 추출
df['year_month'] = df['계약년월'].astype(str)

# '보증금(만원)' 열의 쉼표 제거하고 숫자로 변환
df['보증금(만원)'] = df['보증금(만원)'].str.replace(',', '').astype(float)



# 'year_month'를 월별로 그룹화하여 평균값 계산
monthly_data = df.groupby('year_month')['보증금(만원)'].mean().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='year_month',
    y='보증금(만원)',
    title='김포 월별 오피스텔 전세 평균가격',
    labels={'year_month': '월', '보증금(만원)': '전세(만원)'},
    template='plotly_dark',
    line_shape='linear',
    markers=True,
    width=800,
    height=400,
)

fig.update_yaxes(tickformat=",d")
fig.show()

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('김포데이터/gimpo_multi_complex.csv')

df = df[(df['전월세구분'] == '전세')]

# '계약년월'을 문자열로 변환 후 월 정보 추출
df['year_month'] = df['계약년월'].astype(str)

# '보증금(만원)' 열의 쉼표 제거하고 숫자로 변환
df['보증금(만원)'] = df['보증금(만원)'].str.replace(',', '').astype(float)



# 'year_month'를 월별로 그룹화하여 평균값 계산
monthly_data = df.groupby('year_month')['보증금(만원)'].mean().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='year_month',
    y='보증금(만원)',
    title='김포 월별 연립다세대 전세 평균가격',
    labels={'year_month': '월', '보증금(만원)': '전세(만원)'},
    template='plotly_dark',
    line_shape='linear',
    markers=True,
    width=800,
    height=400,
)

fig.update_yaxes(tickformat=",d")
fig.show()

# %% [markdown]
# ## 김포 월세

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('김포데이터/gimpo_apart.csv', encoding='euc_kr')

# '전월세구분'이 '전세'이고 'HOUSE_GBN_NM'이 '아파트'인 행들만 필터링
df = df[(df['전월세구분'] == '월세')]

# '계약년월'을 문자열로 변환 후 월 정보 추출
df['year_month'] = df['계약년월'].astype(str)

# '보증금(만원)' 열의 쉼표 제거하고 숫자로 변환
df['보증금(만원)'] = df['보증금(만원)'].str.replace(',', '').astype(float)



# 'year_month'를 월별로 그룹화하여 평균값 계산
monthly_data = df.groupby('year_month')['보증금(만원)'].mean().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='year_month',
    y='보증금(만원)',
    title='김포 월별 아파트 월세 보증금 평균가격',
    labels={'year_month': '월', '보증금(만원)': '월세 보증금(만원)'},
    template='plotly_dark',
    line_shape='linear',
    markers=True,
    width=800,
    height=400,
)

fig.update_yaxes(tickformat=",d")
fig.show()

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('김포데이터/gimpo_house.csv')

# '전월세구분'이 '전세'이고 'HOUSE_GBN_NM'이 '아파트'인 행들만 필터링
df = df[(df['전월세구분'] == '월세')]

# '계약년월'을 문자열로 변환 후 월 정보 추출
df['year_month'] = df['계약년월'].astype(str)

# '보증금(만원)' 열의 쉼표 제거하고 숫자로 변환
df['보증금(만원)'] = df['보증금(만원)'].str.replace(',', '').astype(float)



# 'year_month'를 월별로 그룹화하여 평균값 계산
monthly_data = df.groupby('year_month')['보증금(만원)'].mean().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='year_month',
    y='보증금(만원)',
    title='김포 월별 단독다가구 월세 보증금 평균가격',
    labels={'year_month': '월', '보증금(만원)': '월세 보증금(만원)'},
    template='plotly_dark',
    line_shape='linear',
    markers=True,
    width=800,
    height=400,
)

fig.update_yaxes(tickformat=",d")
fig.show()

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('김포데이터/gimpo_multi_complex.csv')

df = df[(df['전월세구분'] == '월세')]

# '계약년월'을 문자열로 변환 후 월 정보 추출
df['year_month'] = df['계약년월'].astype(str)

# '보증금(만원)' 열의 쉼표 제거하고 숫자로 변환
df['보증금(만원)'] = df['보증금(만원)'].str.replace(',', '').astype(float)



# 'year_month'를 월별로 그룹화하여 평균값 계산
monthly_data = df.groupby('year_month')['보증금(만원)'].mean().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='year_month',
    y='보증금(만원)',
    title='김포 월별 연립다세대 월세 보증금 평균가격',
    labels={'year_month': '월', '보증금(만원)': '월세 보증금(만원)'},
    template='plotly_dark',
    line_shape='linear',
    markers=True,
    width=800,
    height=400,
)

fig.update_yaxes(tickformat=",d")
fig.show()

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('김포데이터/gimpo_officetels.csv', encoding='euc_kr')

df = df[(df['전월세구분'] == '월세')]

# '계약년월'을 문자열로 변환 후 월 정보 추출
df['year_month'] = df['계약년월'].astype(str)

# '보증금(만원)' 열의 쉼표 제거하고 숫자로 변환
df['보증금(만원)'] = df['보증금(만원)'].str.replace(',', '').astype(float)



# 'year_month'를 월별로 그룹화하여 평균값 계산
monthly_data = df.groupby('year_month')['보증금(만원)'].mean().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='year_month',
    y='보증금(만원)',
    title='김포 월별 오피스텔 월세 보증금 평균가격',
    labels={'year_month': '월', '보증금(만원)': '월세 보증금(만원)'},
    template='plotly_dark',
    line_shape='linear',
    markers=True,
    width=800,
    height=400,
)

fig.update_yaxes(tickformat=",d")
fig.show()

# %% [markdown]
# ## 서울 전세 거래량 변동 추이 데이터

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/seoul_all.csv', encoding='euc_kr')

# 'RENT_GBN'이 '전세'이고 'HOUSE_GBN_NM'이 '아파트'인 행들만 필터링
df = df[(df['RENT_GBN'] == '전세') & (df['HOUSE_GBN_NM'] == '아파트')]

df = df[['RENT_GTN', 'CNTRCT_DE']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['CNTRCT_DE'].astype(str).str[:-2])['RENT_GTN'].count().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='CNTRCT_DE',
    y='RENT_GTN',
    title='서울 월별 아파트 전세 거래량 변동 추이',
    labels={'CNTRCT_DE': '월', 'RENT_GTN': '아파트 거래량(개)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)

fig.update_yaxes(tickformat=",d")
# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_24000\503823001.py:5: DtypeWarning:
#
# Columns (16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/seoul_all.csv', encoding='euc_kr')

# 'RENT_GBN'이 '전세'이고 'HOUSE_GBN_NM'이 '오피스텔'인 행들만 필터링
df = df[(df['RENT_GBN'] == '전세') & (df['HOUSE_GBN_NM'] == '오피스텔')]

df = df[['RENT_GTN', 'CNTRCT_DE']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['CNTRCT_DE'].astype(str).str[:-2])['RENT_GTN'].count().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='CNTRCT_DE',
    y='RENT_GTN',
    title='서울 월별 오피스텔 전세 거래량 변동 추이',
    labels={'CNTRCT_DE': '월', 'RENT_GTN': '오피스텔 거래량(개)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)

fig.update_yaxes(tickformat=",d")
# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_24000\3554369348.py:5: DtypeWarning:
#
# Columns (16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/seoul_all.csv', encoding='euc_kr')

# 'RENT_GBN'이 '전세'이고 'HOUSE_GBN_NM'이 '연립다세대'인 행들만 필터링
df = df[(df['RENT_GBN'] == '전세') & (df['HOUSE_GBN_NM'] == '연립다세대')]

df = df[['RENT_GTN', 'CNTRCT_DE']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['CNTRCT_DE'].astype(str).str[:-2])['RENT_GTN'].count().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='CNTRCT_DE',
    y='RENT_GTN',
    title='서울 월별 연립다세대 전세 거래량 변동 추이',
    labels={'CNTRCT_DE': '월', 'RENT_GTN': '연립다세대 거래량(개)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)

fig.update_yaxes(tickformat=",d")
# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_24000\1359896678.py:5: DtypeWarning:
#
# Columns (16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/seoul_all.csv', encoding='euc_kr')

# 'RENT_GBN'이 '전세'이고 'HOUSE_GBN_NM'이 '단독다가구'인 행들만 필터링
df = df[(df['RENT_GBN'] == '전세') & (df['HOUSE_GBN_NM'] == '단독다가구')]

df = df[['RENT_GTN', 'CNTRCT_DE']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['CNTRCT_DE'].astype(str).str[:-2])['RENT_GTN'].count().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='CNTRCT_DE',
    y='RENT_GTN',
    title='서울 월별 단독다가구 전세 거래량 변동 추이',
    labels={'CNTRCT_DE': '월', 'RENT_GTN': '단독다가구 거래량(개)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)

fig.update_yaxes(tickformat=",d")
# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_24000\1628813534.py:5: DtypeWarning:
#
# Columns (16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.

# %% [markdown]
# ## 서울 월세 거래량 변동 추이 데이터

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/seoul_all.csv', encoding='euc_kr')

# 'RENT_GBN'이 '월세'이고 'HOUSE_GBN_NM'이 '아파트'인 행들만 필터링
df = df[(df['RENT_GBN'] == '월세') & (df['HOUSE_GBN_NM'] == '아파트')]

df = df[['RENT_GTN', 'CNTRCT_DE']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['CNTRCT_DE'].astype(str).str[:-2])['RENT_GTN'].count().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='CNTRCT_DE',
    y='RENT_GTN',
    title='서울 월별 아파트 월세 거래량 변동 추이',
    labels={'CNTRCT_DE': '월', 'RENT_GTN': '아파트 거래량(개)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)

fig.update_yaxes(tickformat=",d")
# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_24000\1306140326.py:5: DtypeWarning:
#
# Columns (16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/seoul_all.csv', encoding='euc_kr')

# 'RENT_GBN'이 '월세'이고 'HOUSE_GBN_NM'이 '오피스텔'인 행들만 필터링
df = df[(df['RENT_GBN'] == '월세') & (df['HOUSE_GBN_NM'] == '오피스텔')]

df = df[['RENT_GTN', 'CNTRCT_DE']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['CNTRCT_DE'].astype(str).str[:-2])['RENT_GTN'].count().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='CNTRCT_DE',
    y='RENT_GTN',
    title='서울 월별 오피스텔 월세 거래량 변동 추이',
    labels={'CNTRCT_DE': '월', 'RENT_GTN': '오피스텔 거래량(개)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)

fig.update_yaxes(tickformat=",d")
# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_24000\3936715531.py:5: DtypeWarning:
#
# Columns (16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/seoul_all.csv', encoding='euc_kr')

# 'RENT_GBN'이 '월세'이고 'HOUSE_GBN_NM'이 '연립다세대'인 행들만 필터링
df = df[(df['RENT_GBN'] == '월세') & (df['HOUSE_GBN_NM'] == '연립다세대')]

df = df[['RENT_GTN', 'CNTRCT_DE']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['CNTRCT_DE'].astype(str).str[:-2])['RENT_GTN'].count().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='CNTRCT_DE',
    y='RENT_GTN',
    title='서울 월별 연립다세대 월세 거래량 변동 추이',
    labels={'CNTRCT_DE': '월', 'RENT_GTN': '연립다세대 거래량(개)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)

fig.update_yaxes(tickformat=",d")
# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_24000\3484100096.py:5: DtypeWarning:
#
# Columns (16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/seoul_all.csv', encoding='euc_kr')

# 'RENT_GBN'이 '월세'이고 'HOUSE_GBN_NM'이 '단독다가구'인 행들만 필터링
df = df[(df['RENT_GBN'] == '월세') & (df['HOUSE_GBN_NM'] == '단독다가구')]

df = df[['RENT_GTN', 'CNTRCT_DE']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['CNTRCT_DE'].astype(str).str[:-2])['RENT_GTN'].count().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='CNTRCT_DE',
    y='RENT_GTN',
    title='서울 월별 단독다가구 월세 거래량 변동 추이',
    labels={'CNTRCT_DE': '월', 'RENT_GTN': '단독다가구 거래량(개)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)

fig.update_yaxes(tickformat=",d")
# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_24000\343942862.py:5: DtypeWarning:
#
# Columns (16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.

# %% [markdown]
# ## 김포 전세 거래량 변동 추이

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
#df = pd.read_csv('김포데이터/gimpo_apart.csv', encoding='euc_kr')
df = pd.read_csv('김포데이터/gimpo_all2.csv')

# '전월세구분'이 '전세'이고 'HOUSE_GBN_NM'이 '아파트'인 행들만 필터링
df = df[(df['전월세구분'] == '전세') & (df['주택유형'] == '아파트')]

# '계약년월'을 문자열로 변환 후 월 정보 추출
df['year_month'] = df['계약년월'].astype(str)

# '보증금(만원)' 열의 쉼표 제거하고 숫자로 변환
df['보증금(만원)'] = df['보증금(만원)'].str.replace(',', '').astype(float)


monthly_data = df.groupby('year_month')['보증금(만원)'].count().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='year_month',
    y='보증금(만원)',
    title='김포 월별 아파트 전세 거래량 ',
    labels={'year_month': '월', '보증금(만원)': '거래량(개)'},
    template='plotly_dark',
    line_shape='linear',
    markers=True,
    width=800,
    height=400,
)

fig.update_yaxes(tickformat=",d")
fig.show()

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('김포데이터/gimpo_officetels.csv', encoding='euc_kr')

df = df[(df['전월세구분'] == '전세')]

# '계약년월'을 문자열로 변환 후 월 정보 추출
df['year_month'] = df['계약년월'].astype(str)

# '보증금(만원)' 열의 쉼표 제거하고 숫자로 변환
df['보증금(만원)'] = df['보증금(만원)'].str.replace(',', '').astype(float)


monthly_data = df.groupby('year_month')['보증금(만원)'].count().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='year_month',
    y='보증금(만원)',
    title='김포 월별 오피스텔 전세 거래량 ',
    labels={'year_month': '월', '보증금(만원)': '거래량(개)'},
    template='plotly_dark',
    line_shape='linear',
    markers=True,
    width=800,
    height=400,
)

fig.update_yaxes(tickformat=",d")
fig.show()

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('김포데이터/gimpo_house.csv')

df = df[(df['전월세구분'] == '전세')]

# '계약년월'을 문자열로 변환 후 월 정보 추출
df['year_month'] = df['계약년월'].astype(str)

# '보증금(만원)' 열의 쉼표 제거하고 숫자로 변환
df['보증금(만원)'] = df['보증금(만원)'].str.replace(',', '').astype(float)


monthly_data = df.groupby('year_month')['보증금(만원)'].count().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='year_month',
    y='보증금(만원)',
    title='김포 월별 단독다가구 전세 거래량 ',
    labels={'year_month': '월', '보증금(만원)': '거래량(개)'},
    template='plotly_dark',
    line_shape='linear',
    markers=True,
    width=800,
    height=400,
)

fig.update_yaxes(tickformat=",d")
fig.show()

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('김포데이터/gimpo_multi_complex.csv')

df = df[(df['전월세구분'] == '전세')]

# '계약년월'을 문자열로 변환 후 월 정보 추출
df['year_month'] = df['계약년월'].astype(str)

# '보증금(만원)' 열의 쉼표 제거하고 숫자로 변환
df['보증금(만원)'] = df['보증금(만원)'].str.replace(',', '').astype(float)


monthly_data = df.groupby('year_month')['보증금(만원)'].count().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='year_month',
    y='보증금(만원)',
    title='김포 월별 연립다세대 전세 거래량 ',
    labels={'year_month': '월', '보증금(만원)': '거래량(개)'},
    template='plotly_dark',
    line_shape='linear',
    markers=True,
    width=800,
    height=400,
)

fig.update_yaxes(tickformat=",d")
fig.show()

# %% [markdown]
# ## 김포 월세 거래량 변동 추이

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('김포데이터/gimpo_apart.csv', encoding='euc_kr')

# '전월세구분'이 '전세'이고 'HOUSE_GBN_NM'이 '아파트'인 행들만 필터링
df = df[(df['전월세구분'] == '월세')]

# '계약년월'을 문자열로 변환 후 월 정보 추출
df['year_month'] = df['계약년월'].astype(str)

# '보증금(만원)' 열의 쉼표 제거하고 숫자로 변환
df['보증금(만원)'] = df['보증금(만원)'].str.replace(',', '').astype(float)


monthly_data = df.groupby('year_month')['보증금(만원)'].count().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='year_month',
    y='보증금(만원)',
    title='김포 월별 아파트 월세 거래량 ',
    labels={'year_month': '월', '보증금(만원)': '거래량(개)'},
    template='plotly_dark',
    line_shape='linear',
    markers=True,
    width=800,
    height=400,
)

fig.update_yaxes(tickformat=",d")
fig.show()

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('김포데이터/gimpo_officetels.csv', encoding='euc_kr')

df = df[(df['전월세구분'] == '월세')]

# '계약년월'을 문자열로 변환 후 월 정보 추출
df['year_month'] = df['계약년월'].astype(str)

# '보증금(만원)' 열의 쉼표 제거하고 숫자로 변환
df['보증금(만원)'] = df['보증금(만원)'].str.replace(',', '').astype(float)


monthly_data = df.groupby('year_month')['보증금(만원)'].count().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='year_month',
    y='보증금(만원)',
    title='김포 월별 오피스텔 월세 거래량 ',
    labels={'year_month': '월', '보증금(만원)': '거래량(개)'},
    template='plotly_dark',
    line_shape='linear',
    markers=True,
    width=800,
    height=400,
)

fig.update_yaxes(tickformat=",d")
fig.show()

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('김포데이터/gimpo_house.csv')

df = df[(df['전월세구분'] == '월세')]

# '계약년월'을 문자열로 변환 후 월 정보 추출
df['year_month'] = df['계약년월'].astype(str)

# '보증금(만원)' 열의 쉼표 제거하고 숫자로 변환
df['보증금(만원)'] = df['보증금(만원)'].str.replace(',', '').astype(float)


monthly_data = df.groupby('year_month')['보증금(만원)'].count().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='year_month',
    y='보증금(만원)',
    title='김포 월별 단독다가구 월세 거래량 ',
    labels={'year_month': '월', '보증금(만원)': '거래량(개)'},
    template='plotly_dark',
    line_shape='linear',
    markers=True,
    width=800,
    height=400,
)

fig.update_yaxes(tickformat=",d")
fig.show()

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('김포데이터/gimpo_multi_complex.csv')

df = df[(df['전월세구분'] == '월세')]

# '계약년월'을 문자열로 변환 후 월 정보 추출
df['year_month'] = df['계약년월'].astype(str)

# '보증금(만원)' 열의 쉼표 제거하고 숫자로 변환
df['보증금(만원)'] = df['보증금(만원)'].str.replace(',', '').astype(float)


monthly_data = df.groupby('year_month')['보증금(만원)'].count().reset_index()

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='year_month',
    y='보증금(만원)',
    title='김포 월별 연립다세대 월세 거래량 ',
    labels={'year_month': '월', '보증금(만원)': '거래량(개)'},
    template='plotly_dark',
    line_shape='linear',
    markers=True,
    width=800,
    height=400,
)

fig.update_yaxes(tickformat=",d")
fig.show()

# %% [markdown]
# ## 거래량 순위

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/before_mega_seoul.csv')

df = df[['SGG_NM', 'CNTRCT_DE']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['SGG_NM'].astype(str))['CNTRCT_DE'].count().reset_index()

# 내림차순 정렬
monthly_data = monthly_data.sort_values(by='CNTRCT_DE', ascending=False)

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='SGG_NM',
    y='CNTRCT_DE',
    title='메가 서울 발표 전 서울 구별 전월세 거래 순위',
    labels={'SGG_NM': '구', 'CNTRCT_DE': '거래량(개)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)
fig.update_yaxes(tickformat=",d")
# Show the plot
fig.show()

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/after_mega_seoul.csv')

df = df[['SGG_NM', 'CNTRCT_DE']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['SGG_NM'].astype(str))['CNTRCT_DE'].count().reset_index()

# 내림차순 정렬
monthly_data = monthly_data.sort_values(by='CNTRCT_DE', ascending=False)

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='SGG_NM',
    y='CNTRCT_DE',
    title='메가 서울 발표 후 서울 구별 전월세 거래 순위',
    labels={'SGG_NM': '구', 'CNTRCT_DE': '거래량(개)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)

fig.update_yaxes(tickformat=",d")
# Show the plot
fig.show()

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/seoul_all.csv', encoding='euc_kr')

df = df[['SGG_NM', 'CNTRCT_DE']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['SGG_NM'].astype(str))['CNTRCT_DE'].count().reset_index()

# 내림차순 정렬
monthly_data = monthly_data.sort_values(by='CNTRCT_DE', ascending=False)

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='SGG_NM',
    y='CNTRCT_DE',
    title='서울 구별 전월세 거래 순위',
    labels={'SGG_NM': '구', 'CNTRCT_DE': '거래량(건)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)
fig.update_yaxes(tickformat=",d")
# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_24000\2339558849.py:5: DtypeWarning:
#
# Columns (16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('서울전체/before_mega_seoul.csv')

# 'RENT_GBN'이 '전세'이고 'HOUSE_GBN_NM'이 '아파트'인 행들만 필터링
df = df[(df['RENT_GBN'] == '전세') & (df['HOUSE_GBN_NM'] == '아파트')]
df = df[['SGG_NM', 'RENT_GTN']]

# 'RENT_GTN'을 월 별로 그룹화하여 평균값 계산
monthly_data = df.groupby(df['SGG_NM'].astype(str))['RENT_GTN'].mean().reset_index()

# 내림차순 정렬
monthly_data = monthly_data.sort_values(by='RENT_GTN', ascending=False)

# 선 그래프 그리기
fig = px.line(
    monthly_data,
    x='SGG_NM',
    y='RENT_GTN',
    title='메가 서울 발표 전 서울 구별 아파트 전월세 평균 보증금 순위',
    labels={'SGG_NM': '구', 'RENT_GTN': '평균 보증금(만원)'},
    template='plotly_dark',  # Dark mode template
    line_shape='linear',  # Linear interpolation between points
    markers=True,  # Show markers on data points
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)
fig.update_yaxes(tickformat=",d")
# Show the plot
fig.show()

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
before_mega = pd.read_csv('서울전체/before_mega_seoul.csv')
after_mega = pd.read_csv('서울전체/after_mega_seoul.csv')

# 'RENT_GBN'이 '전세'이고 'HOUSE_GBN_NM'이 '아파트'인 행들만 필터링
before_mega = before_mega[(before_mega['RENT_GBN'] == '전세') & (before_mega['HOUSE_GBN_NM'] == '아파트')]
after_mega = after_mega[(after_mega['RENT_GBN'] == '전세') & (after_mega['HOUSE_GBN_NM'] == '아파트')]

# 각 데이터프레임에서 아파트 전세 보증금 평균 계산
before_mega_avg = before_mega.groupby('SGG_NM')['RENT_GTN'].mean().reset_index()
after_mega_avg = after_mega.groupby('SGG_NM')['RENT_GTN'].mean().reset_index()

# 두 데이터프레임을 합치기 (for plotting)
merged_data = pd.concat([before_mega_avg.assign(dataset='Before Mega Seoul'), 
                         after_mega_avg.assign(dataset='After Mega Seoul')])

# 막대 차트 그리기
fig = px.bar(
    merged_data,
    x='SGG_NM',
    y='RENT_GTN',
    color='dataset',
    title='Before Mega Seoul vs After Mega Seoul 아파트 전세 보증금 평균 비교',
    labels={'SGG_NM': '구', 'RENT_GTN': '평균 보증금(만원)'},
    template='plotly_dark',  # Dark mode template
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)
fig.update_yaxes(tickformat=",d")
# Show the plot
fig.show()

# %% [markdown]
# ## 메가 서울 발표 전 후  서울 전체 거래량 비교

# %%
df_seoul = pd.read_csv("서울전체/df_서울.csv")

before_seoul = df_seoul.loc[df_seoul['발표'] == '발표전', :]
after_seoul = df_seoul.loc[df_seoul['발표'] == '발표후', :]

before_avg = before_seoul.groupby('자치구명')['물건금액(만원)'].count().reset_index()
after_avg = after_seoul.groupby('자치구명')['물건금액(만원)'].count().reset_index()

merge_df = pd.concat([before_avg.assign(발표='발표전'), after_avg.assign(발표='발표후')])

fig = px.bar(merge_df,
            x='자치구명',
            y='물건금액(만원)',
            color='발표',
            barmode='group',
            title='발표 전 후 서울 매매 총거래  비교',
            labels={'자치구명': '구', '물건금액(만원)': '거래량(건)'},
            template='plotly_dark',  # Dark mode template
            width=900,  # Width of the plot
            height=500,  # Height of the plo
            )

for sgg in merge_df['자치구명'].unique():
    before_count = before_avg[before_avg['자치구명'] == sgg]['물건금액(만원)'].values[0]
    after_count = after_avg[after_avg['자치구명'] == sgg]['물건금액(만원)'].values[0]
    percent_increase = ((after_count - before_count) / before_count) * 100
    fig.add_annotation(
        x=sgg,
        y=max(before_count, after_count),
        text=f'{percent_increase:.2f}%',
        showarrow=True,
        arrowcolor='red',
        arrowhead=4,
        ax=0,
        ay=-40
    )
    
fig.show()

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장

df = pd.read_csv('서울전체/seoul_all.csv', encoding='euc_kr')
before_mega = df[df['MEGASEOUL'] == 'Before']
after_mega = df[df['MEGASEOUL'] == 'After']

# 각 데이터프레임에서 아파트 전세 보증금 평균 계산
before_mega_avg = before_mega.groupby('SGG_NM')['RENT_GTN'].count().reset_index()
after_mega_avg = after_mega.groupby('SGG_NM')['RENT_GTN'].count().reset_index()

# 두 데이터프레임을 합치기 (for plotting)
merged_data = pd.concat([before_mega_avg.assign(dataset='Before Mega Seoul'), 
                         after_mega_avg.assign(dataset='After Mega Seoul')])

# 막대 차트 그리기
fig = px.bar(
    merged_data,
    x='SGG_NM',
    y='RENT_GTN',
    color='dataset',
    barmode='group',
    title='서울특별시 구별 전월세 총거래량 비교',
    labels={'SGG_NM': '구', 'RENT_GTN': '거래량(건)'},
    template='plotly_dark',  # Dark mode template
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)

# After Mega Seoul 대비 거래량 증가 비율 계산 및 텍스트로 추가
for sgg in merged_data['SGG_NM'].unique():
    before_count = before_mega_avg[before_mega_avg['SGG_NM'] == sgg]['RENT_GTN'].values[0]
    after_count = after_mega_avg[after_mega_avg['SGG_NM'] == sgg]['RENT_GTN'].values[0]
    percent_increase = ((after_count - before_count) / before_count) * 100

    fig.add_annotation(
        x=sgg,
        y=max(before_count, after_count),
        text=f'{percent_increase:.2f}%',
        showarrow=True,
        arrowcolor='red',
        arrowhead=4,
        ax=0,
        ay=-40
    )

fig.update_yaxes(tickformat=",d")
# Show the plot
fig.show()
# Out:
# C:\Users\chlwl\AppData\Local\Temp\ipykernel_15452\2114476782.py:8: DtypeWarning:
#
# Columns (16,21,22) have mixed types. Specify dtype option on import or set low_memory=False.

# %% [markdown]
# ## 메가 서울 발표 전 후 김포 전체 거래량 비교

# %%
df_김포=pd.read_csv("김포데이터/df_김포.csv")

df_김포_발표전=df_김포.loc[df_김포['발표']=='발표전', :]
df_김포_발표후=df_김포.loc[df_김포['발표']=='발표후', :]

김포_before_avg=df_김포_발표전.groupby('시군구')['거래금액(만원)'].count().reset_index()
김포_after_avg=df_김포_발표후.groupby('시군구')['거래금액(만원)'].count().reset_index()

병합데이터=pd.concat([김포_before_avg.assign(발표='발표전'),김포_after_avg.assign(발표='발표후')])


fig = px.bar(병합데이터,
            x='시군구',
            y='거래금액(만원)',
            color='발표',
            barmode='group',
            title='발표 전 후 김포 총거래 비교',
            labels={'시군구': '시군구', '거래금액(만원)': '거래량(건)'},
            template='plotly_dark',  # Dark mode template
            width=900,  # Width of the plot
            height=500,)

for sgg in 김포병합['시군구'].unique():
    before_count = 김포B[김포B['시군구'] == sgg]['거래금액(만원)'].values[0]
    after_count = 김포A[김포A['시군구'] == sgg]['거래금액(만원)'].values[0]
    percent_increase = ((after_count - before_count) / before_count) * 100
    fig.add_annotation(
        x=sgg,
        y=max(before_count, after_count),
        text=f'{percent_increase:.2f}%',
        showarrow=True,
        arrowcolor='red',
        arrowhead=4,
        ax=0,
        ay=-40
    )

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[251], line 23
#       9 병합데이터=pd.concat([김포_before_avg.assign(발표='발표전'),김포_after_avg.assign(발표='발표후')])
#      12 fig = px.bar(병합데이터,
#      13             x='시군구',
#      14             y='거래금액(만원)',
#    (...)
#      20             width=900,  # Width of the plot
#      21             height=500,)
# ---> 23 for sgg in 김포병합['시군구'].unique():
#      24     before_count = 김포B[김포B['시군구'] == sgg]['거래금액(만원)'].values[0]
#      25     after_count = 김포A[김포A['시군구'] == sgg]['거래금액(만원)'].values[0]
#
# NameError: name '김포병합' is not defined

# %%
import pandas as pd
import plotly.express as px

# CSV 파일을 읽어와 데이터프레임으로 저장
df = pd.read_csv('김포데이터/gimpo_all2.csv')
# '계약년월'을 문자열로 변환 후
df['year_month'] = df['계약년월'].astype(str)
df['시군구'] = df['시군구'].str[8:11]


before_mega = df[(df['year_month'] <= '202309')]
after_mega = df[(df['year_month'] >= '202310')]

before_mega_cnt = before_mega.groupby('시군구')['계약일'].count().reset_index()
after_mega_cnt = after_mega.groupby('시군구')['계약일'].count().reset_index()



# 두 데이터프레임을 합치기 (for plotting)
merged_data = pd.concat([before_mega_cnt.assign(dataset='Before Mega Seoul'), 
                         after_mega_cnt.assign(dataset='After Mega Seoul')])

# 막대 차트 그리기
fig = px.bar(
    merged_data,
    x='시군구',
    y='계약일',
    color='dataset',
    barmode='group',
    title='Before Mega Seoul vs After Mega Seoul 김포 총거래  비교',
    labels={'시군구': '행정구역', '계약일': '거래량(건)'},
    template='plotly_dark',  # Dark mode template
    width=800,  # Width of the plot
    height=400,  # Height of the plot
)

# After Mega Seoul 대비 거래량 증가 비율 계산 및 텍스트로 추가
for sgg in merged_data['시군구'].unique():
    before_count = before_mega_cnt[before_mega_cnt['시군구'] == sgg]['계약일'].values[0]
    after_count = after_mega_cnt[after_mega_cnt['시군구'] == sgg]['계약일'].values[0]
    percent_increase = ((after_count - before_count) / before_count) * 100

    fig.add_annotation(
        x=sgg,
        y=max(before_count, after_count),
        text=f'{percent_increase:.2f}%',
        showarrow=True,
        arrowcolor='red',
        arrowhead=4,
        ax=0,
        ay=-40
    )

fig.update_yaxes(tickformat=",d")
# Show the plot
fig.show()
